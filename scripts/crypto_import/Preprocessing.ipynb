# %%
import pandas as pd
import numpy as np
import itertools
base_path = 'data'

# %%
# SYMBOLS = ['BTCUSDT', 'ETHUSDT', 'ADAUSDT', 'BNBUSDT', 'XRPUSDT', 'SOLUSDT', 'DOTUSDT', 'DOGEUSDT', 'AVAXUSDT', 'UNIUSDT']
SYMBOLS = ['NEOUSDT', 'LTCUSDT', 'EOSUSDT', 'XLMUSDT', 'SHIBUSDT', 
           'IOTAUSDT', 'ETCUSDT', 'LINKUSDT', 'XMRUSDT', 
           'MATICUSDT', 'ALGOUSDT', 'MANAUSDT', 'APEUSDT', 'FTMUSDT', 
           'GMTUSDT', 'BONDUSDT', 'ATOMUSDT', 'NEARUSDT', 'RUNEUSDT', 
           'SANDUSDT', 'WAVESUSDT', 'TRXUSDT']
RES_LIST = ['1min', '5min', '1h', '1d']

# %%
def preprocess_crypto(sym, res):
    filename = f"{sym}_{res}.csv"
    print(f"Handling {filename}")
    df = pd.read_csv(f"{base_path}/{sym}_{res}.csv", index_col=0)
    countBefore = df.shape[0]
    # round down to nearest minute (ignore seconds)
    df['date'] = df['date'].values.astype('<M8[m]')
    df['date'] = df['date'].astype(str)
    df = df.sort_values(['date', 'tic']).reset_index(drop=True)

    # insert missing rows from date_range
    if res == '1d':
        df['date'] = pd.to_datetime(df['date']).dt.date.astype('str')   
    list_date = list(pd.date_range(df['date'].min(), df['date'].max(), freq=res).astype(str))
    countExpected = len(list_date)    
    list_ticker = df["tic"].unique().tolist()
    combination = list(itertools.product(list_date, list_ticker))
    combination_df =  pd.DataFrame(combination, columns=["date", "tic"])
    processed_full = combination_df.merge(df, on=["date", "tic"], how="left")

    # forward-filling close price to OHLC, set Vol to 0
    processed_full[['close']] = processed_full[['close']].fillna(method='ffill')
    processed_full.volume.fillna(0, inplace=True) # [['volume']] = processed_full[['volume']].fillna(0)
    processed_full.open.fillna(processed_full.close, inplace=True)
    processed_full.high.fillna(processed_full.close, inplace=True)
    processed_full.low.fillna(processed_full.close, inplace=True)
    processed_full['datex'] = pd.to_datetime(processed_full['date'])
    processed_full['day'] = processed_full.datex.dt.day_of_week
    processed_full = processed_full.drop('datex', axis=1)
    processed_full = processed_full.reset_index(drop=True)
    countNew = processed_full.shape[0]
    # processed_full.open.fillna(processed_full.close, inplace=True)
    print(f"Start: {countBefore} Expected: {countExpected} New: {countNew} Diff.: {countNew-countExpected}")
    print(f"Added: {countNew-countBefore}")
    print("----------------------------------------------------------")

    processed_full.to_csv(f"{base_path}/new/{sym}_{res}.csv")
    return processed_full

# %%
# res = '1d'
# sym = 'BTCUSDT'
# df = preprocess_crypto(sym, res)

# %%
for sym in SYMBOLS:
    for res in RES_LIST:
        df = preprocess_crypto(sym, res)
# Out:
# Handling NEOUSDT_1min.csv
# Start: 2415388 Expected: 2423520 New: 2423520 Diff.: 0
# Added: 8132
# ----------------------------------------------------------
# Handling NEOUSDT_5min.csv
# Start: 483088 Expected: 484704 New: 484704 Diff.: 0
# Added: 1616
# ----------------------------------------------------------
# Handling NEOUSDT_1h.csv
# Start: 40271 Expected: 40392 New: 40392 Diff.: 0
# Added: 121
# ----------------------------------------------------------
# Handling NEOUSDT_1d.csv
# Start: 1683 Expected: 1683 New: 1683 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling LTCUSDT_1min.csv
# Start: 2382316 Expected: 2390400 New: 2390400 Diff.: 0
# Added: 8084
# ----------------------------------------------------------
# Handling LTCUSDT_5min.csv
# Start: 476472 Expected: 478080 New: 478080 Diff.: 0
# Added: 1608
# ----------------------------------------------------------
# Handling LTCUSDT_1h.csv
# Start: 39719 Expected: 39840 New: 39840 Diff.: 0
# Added: 121
# ----------------------------------------------------------
# Handling LTCUSDT_1d.csv
# Start: 1660 Expected: 1660 New: 1660 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling EOSUSDT_1min.csv
# Start: 2145537 Expected: 2151360 New: 2151360 Diff.: 0
# Added: 5823
# ----------------------------------------------------------
# Handling EOSUSDT_5min.csv
# Start: 429112 Expected: 430272 New: 430272 Diff.: 0
# Added: 1160
# ----------------------------------------------------------
# Handling EOSUSDT_1h.csv
# Start: 35769 Expected: 35856 New: 35856 Diff.: 0
# Added: 87
# ----------------------------------------------------------
# Handling EOSUSDT_1d.csv
# Start: 1494 Expected: 1494 New: 1494 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling XLMUSDT_1min.csv
# Start: 2141218 Expected: 2147040 New: 2147040 Diff.: 0
# Added: 5822
# ----------------------------------------------------------
# Handling XLMUSDT_5min.csv
# Start: 428248 Expected: 429408 New: 429408 Diff.: 0
# Added: 1160
# ----------------------------------------------------------
# Handling XLMUSDT_1h.csv
# Start: 35697 Expected: 35784 New: 35784 Diff.: 0
# Added: 87
# ----------------------------------------------------------
# Handling XLMUSDT_1d.csv
# Start: 1491 Expected: 1491 New: 1491 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling SHIBUSDT_1min.csv
# Start: 598650 Expected: 599040 New: 599040 Diff.: 0
# Added: 390
# ----------------------------------------------------------
# Handling SHIBUSDT_5min.csv
# Start: 119730 Expected: 119808 New: 119808 Diff.: 0
# Added: 78
# ----------------------------------------------------------
# Handling SHIBUSDT_1h.csv
# Start: 9978 Expected: 9984 New: 9984 Diff.: 0
# Added: 6
# ----------------------------------------------------------
# Handling SHIBUSDT_1d.csv
# Start: 416 Expected: 416 New: 416 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling IOTAUSDT_1min.csv
# Start: 2141217 Expected: 2147040 New: 2147040 Diff.: 0
# Added: 5823
# ----------------------------------------------------------
# Handling IOTAUSDT_5min.csv
# Start: 428248 Expected: 429408 New: 429408 Diff.: 0
# Added: 1160
# ----------------------------------------------------------
# Handling IOTAUSDT_1h.csv
# Start: 35697 Expected: 35784 New: 35784 Diff.: 0
# Added: 87
# ----------------------------------------------------------
# Handling IOTAUSDT_1d.csv
# Start: 1491 Expected: 1491 New: 1491 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling ETCUSDT_1min.csv
# Start: 2123937 Expected: 2129760 New: 2129760 Diff.: 0
# Added: 5823
# ----------------------------------------------------------
# Handling ETCUSDT_5min.csv
# Start: 424792 Expected: 425952 New: 425952 Diff.: 0
# Added: 1160
# ----------------------------------------------------------
# Handling ETCUSDT_1h.csv
# Start: 35409 Expected: 35496 New: 35496 Diff.: 0
# Added: 87
# ----------------------------------------------------------
# Handling ETCUSDT_1d.csv
# Start: 1479 Expected: 1479 New: 1479 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling LINKUSDT_1min.csv
# Start: 1811810 Expected: 1815840 New: 1815840 Diff.: 0
# Added: 4030
# ----------------------------------------------------------
# Handling LINKUSDT_5min.csv
# Start: 362366 Expected: 363168 New: 363168 Diff.: 0
# Added: 802
# ----------------------------------------------------------
# Handling LINKUSDT_1h.csv
# Start: 30205 Expected: 30264 New: 30264 Diff.: 0
# Added: 59
# ----------------------------------------------------------
# Handling LINKUSDT_1d.csv
# Start: 1261 Expected: 1261 New: 1261 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling XMRUSDT_1min.csv
# Start: 1728650 Expected: 1732320 New: 1732320 Diff.: 0
# Added: 3670
# ----------------------------------------------------------
# Handling XMRUSDT_5min.csv
# Start: 345734 Expected: 346464 New: 346464 Diff.: 0
# Added: 730
# ----------------------------------------------------------
# Handling XMRUSDT_1h.csv
# Start: 28819 Expected: 28872 New: 28872 Diff.: 0
# Added: 53
# ----------------------------------------------------------
# Handling XMRUSDT_1d.csv
# Start: 1203 Expected: 1203 New: 1203 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling MATICUSDT_1min.csv
# Start: 1668170 Expected: 1671840 New: 1671840 Diff.: 0
# Added: 3670
# ----------------------------------------------------------
# Handling MATICUSDT_5min.csv
# Start: 333638 Expected: 334368 New: 334368 Diff.: 0
# Added: 730
# ----------------------------------------------------------
# Handling MATICUSDT_1h.csv
# Start: 27811 Expected: 27864 New: 27864 Diff.: 0
# Added: 53
# ----------------------------------------------------------
# Handling MATICUSDT_1d.csv
# Start: 1161 Expected: 1161 New: 1161 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling ALGOUSDT_1min.csv
# Start: 1588190 Expected: 1591200 New: 1591200 Diff.: 0
# Added: 3010
# ----------------------------------------------------------
# Handling ALGOUSDT_5min.csv
# Start: 317642 Expected: 318240 New: 318240 Diff.: 0
# Added: 598
# ----------------------------------------------------------
# Handling ALGOUSDT_1h.csv
# Start: 26477 Expected: 26520 New: 26520 Diff.: 0
# Added: 43
# ----------------------------------------------------------
# Handling ALGOUSDT_1d.csv
# Start: 1105 Expected: 1105 New: 1105 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling MANAUSDT_1min.csv
# Start: 996556 Expected: 997920 New: 997920 Diff.: 0
# Added: 1364
# ----------------------------------------------------------
# Handling MANAUSDT_5min.csv
# Start: 199313 Expected: 199584 New: 199584 Diff.: 0
# Added: 271
# ----------------------------------------------------------
# Handling MANAUSDT_1h.csv
# Start: 16613 Expected: 16632 New: 16632 Diff.: 0
# Added: 19
# ----------------------------------------------------------
# Handling MANAUSDT_1d.csv
# Start: 693 Expected: 693 New: 693 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling APEUSDT_1min.csv
# Start: 151200 Expected: 151200 New: 151200 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling APEUSDT_5min.csv
# Start: 30240 Expected: 30240 New: 30240 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling APEUSDT_1h.csv
# Start: 2520 Expected: 2520 New: 2520 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling APEUSDT_1d.csv
# Start: 105 Expected: 105 New: 105 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling FTMUSDT_1min.csv
# Start: 1602590 Expected: 1605600 New: 1605600 Diff.: 0
# Added: 3010
# ----------------------------------------------------------
# Handling FTMUSDT_5min.csv
# Start: 320522 Expected: 321120 New: 321120 Diff.: 0
# Added: 598
# ----------------------------------------------------------
# Handling FTMUSDT_1h.csv
# Start: 26717 Expected: 26760 New: 26760 Diff.: 0
# Added: 43
# ----------------------------------------------------------
# Handling FTMUSDT_1d.csv
# Start: 1115 Expected: 1115 New: 1115 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling GMTUSDT_1min.csv
# Start: 162720 Expected: 162720 New: 162720 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling GMTUSDT_5min.csv
# Start: 32544 Expected: 32544 New: 32544 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling GMTUSDT_1h.csv
# Start: 2712 Expected: 2712 New: 2712 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling GMTUSDT_1d.csv
# Start: 113 Expected: 113 New: 113 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling BONDUSDT_1min.csv
# Start: 518010 Expected: 518400 New: 518400 Diff.: 0
# Added: 390
# ----------------------------------------------------------
# Handling BONDUSDT_5min.csv
# Start: 103602 Expected: 103680 New: 103680 Diff.: 0
# Added: 78
# ----------------------------------------------------------
# Handling BONDUSDT_1h.csv
# Start: 8634 Expected: 8640 New: 8640 Diff.: 0
# Added: 6
# ----------------------------------------------------------
# Handling BONDUSDT_1d.csv
# Start: 360 Expected: 360 New: 360 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling ATOMUSDT_1min.csv
# Start: 1663849 Expected: 1667520 New: 1667520 Diff.: 0
# Added: 3671
# ----------------------------------------------------------
# Handling ATOMUSDT_5min.csv
# Start: 332774 Expected: 333504 New: 333504 Diff.: 0
# Added: 730
# ----------------------------------------------------------
# Handling ATOMUSDT_1h.csv
# Start: 27739 Expected: 27792 New: 27792 Diff.: 0
# Added: 53
# ----------------------------------------------------------
# Handling ATOMUSDT_1d.csv
# Start: 1158 Expected: 1158 New: 1158 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling NEARUSDT_1min.csv
# Start: 897196 Expected: 898560 New: 898560 Diff.: 0
# Added: 1364
# ----------------------------------------------------------
# Handling NEARUSDT_5min.csv
# Start: 179441 Expected: 179712 New: 179712 Diff.: 0
# Added: 271
# ----------------------------------------------------------
# Handling NEARUSDT_1h.csv
# Start: 14957 Expected: 14976 New: 14976 Diff.: 0
# Added: 19
# ----------------------------------------------------------
# Handling NEARUSDT_1d.csv
# Start: 624 Expected: 624 New: 624 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling RUNEUSDT_1min.csv
# Start: 954796 Expected: 956160 New: 956160 Diff.: 0
# Added: 1364
# ----------------------------------------------------------
# Handling RUNEUSDT_5min.csv
# Start: 190961 Expected: 191232 New: 191232 Diff.: 0
# Added: 271
# ----------------------------------------------------------
# Handling RUNEUSDT_1h.csv
# Start: 15917 Expected: 15936 New: 15936 Diff.: 0
# Added: 19
# ----------------------------------------------------------
# Handling RUNEUSDT_1d.csv
# Start: 664 Expected: 664 New: 664 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling SANDUSDT_1min.csv
# Start: 985036 Expected: 986400 New: 986400 Diff.: 0
# Added: 1364
# ----------------------------------------------------------
# Handling SANDUSDT_5min.csv
# Start: 197009 Expected: 197280 New: 197280 Diff.: 0
# Added: 271
# ----------------------------------------------------------
# Handling SANDUSDT_1h.csv
# Start: 16421 Expected: 16440 New: 16440 Diff.: 0
# Added: 19
# ----------------------------------------------------------
# Handling SANDUSDT_1d.csv
# Start: 685 Expected: 685 New: 685 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling WAVESUSDT_1min.csv
# Start: 1808930 Expected: 1812960 New: 1812960 Diff.: 0
# Added: 4030
# ----------------------------------------------------------
# Handling WAVESUSDT_5min.csv
# Start: 361790 Expected: 362592 New: 362592 Diff.: 0
# Added: 802
# ----------------------------------------------------------
# Handling WAVESUSDT_1h.csv
# Start: 30157 Expected: 30216 New: 30216 Diff.: 0
# Added: 59
# ----------------------------------------------------------
# Handling WAVESUSDT_1d.csv
# Start: 1259 Expected: 1259 New: 1259 Diff.: 0
# Added: 0
# ----------------------------------------------------------
# Handling TRXUSDT_1min.csv
# Start: 2125378 Expected: 2131200 New: 2131200 Diff.: 0
# Added: 5822
# ----------------------------------------------------------
# Handling TRXUSDT_5min.csv
# Start: 425080 Expected: 426240 New: 426240 Diff.: 0
# Added: 1160
# ----------------------------------------------------------
# Handling TRXUSDT_1h.csv
# Start: 35433 Expected: 35520 New: 35520 Diff.: 0
# Added: 87
# ----------------------------------------------------------
# Handling TRXUSDT_1d.csv
# Start: 1480 Expected: 1480 New: 1480 Diff.: 0
# Added: 0
# ----------------------------------------------------------

# %%
# processed_full[processed_full['date'] > '2021-04-20 04:10:00'].head(10)
# isnan = processed_full[processed_full['date'].isin(df['date']) == False]
