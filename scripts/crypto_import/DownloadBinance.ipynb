# %%
import numpy as np
import pandas as pd
import requests
import datetime
import time
REQUEST_LIMIT_1MIN = 1200

# %%
def find_first_candlestick(symbol):
    
    info_url = f'https://api.binance.com/api/v3/klines?symbol={symbol}&interval=1m&limit=1&startTime=1'
    info_r = requests.get(info_url)
    info = info_r.json()
    df = pd.DataFrame(info)
    if not df.empty:
        df.columns =['timestamp', 'open', 'high', 'low', 'close', 'vol', 'ct', 'qat', 'not', 'basevol', 'quotevol', 'ignore']
        df = df.drop(columns=['ct', 'qat', 'not', 'basevol', 'quotevol', 'ignore'])
        ts = int(df.iloc[0].timestamp/1000)
        print(f"First Timestamp of {symbol} is at {datetime.datetime.fromtimestamp(ts)}")
        return ts
    return 0

def get_unix_ts(year, month, day, hour, minute):
    dt = datetime.datetime(year, month, day, hour, minute, tzinfo=datetime.timezone.utc)
    return int(datetime.datetime.timestamp(dt))

def get_binance_ohlc(symbol, start, limit=1000):
    start_ms = start * 1000
    info_url = f'https://api.binance.com/api/v3/klines?symbol={symbol}&interval=1m&limit={limit}&startTime={start_ms}'
    info_r = requests.get(info_url)
    info = info_r.json()
    current_limit = info_r.headers['x-mbx-used-weight-1m']
    
    
    data = pd.DataFrame(info)
    if not data.empty:
        data.columns =['timestamp', 'open', 'high', 'low', 'close', 'volume', 'ct', 'qat', 'not', 'basevol', 'quotevol', 'ignore']
        data = data.drop(columns=['ct', 'qat', 'not', 'basevol', 'quotevol', 'ignore'])    
        if len(data) > 0:
            data.timestamp = data.timestamp / 1000
            data['timestamp'] = data['timestamp'].astype(np.int)
            data['volume'] = data['volume'].astype(np.double)
            data['open'] = data['open'].astype(np.double)
            data['high'] = data['high'].astype(np.double)
            data['low'] = data['low'].astype(np.double)
            data['close'] = data['close'].astype(np.double)
            data = data.set_index('timestamp')
            return data, current_limit
    return pd.DataFrame(), current_limit

def append_data_to_file(file, df):
    df.to_csv(f"data/{file}", mode='a', header=False)
    
def load_year(symbol, year):
    print(f"{symbol} - {y}")
    start_time = get_unix_ts(year, 1, 1, 0, 0)
    if year == 2022:
        end_time = get_unix_ts(year,6,30,23,59)
    else:
        end_time = get_unix_ts(year,12,31,23,59)
    filename = f"binance_{symbol}_{year}.csv"
    load(symbol, start_time, end_time, filename)
    
    
# load specific dates
# load('btcusd', get_unix_ts(2011, 8, 10, 0, 0), get_unix_ts(2011,12,31,23,59), 'bitstamp_btcusd.csv')
def load(symbol, start, end, filename):
    current_start = start
    counter = 0
    skipped = 0
    added = 0
    last_time = time.time()
    total_start = time.time()
    while True:
        if current_start < end:
            new_data, current_limit = get_binance_ohlc(symbol, current_start)
            if new_data.empty:
                skipped += 1000
                current_start = current_start + (60*1000)
            else:                
                new_data = new_data[new_data.index <= end]
                last_timestamp = new_data.last_valid_index()
                if last_timestamp:
                    current_start = last_timestamp + 60                          
                    append_data_to_file(filename, new_data)
                    added += len(new_data)
                else:
                    skipped += 1000
                    current_start = current_start + (60*1000)
            counter += 1
            if counter % 43 == 0:
                current_time = time.time()
                time_diff = int(current_time - last_time)
                req_per_sec = int((43 / time_diff) * 10)/10
                limit_remaining = REQUEST_LIMIT_1MIN - int(current_limit)
                print(f"  iteration {counter:03} completed in {time_diff}s, avg {req_per_sec} r/sec, next={datetime.datetime.fromtimestamp(current_start)}, rate-limit={limit_remaining}")
                if limit_remaining < 50:
                    print("rate limit protection - sleep 30s")
                    time.sleep(30)
                last_time = current_time
        else:            
            break
    total_time = int(time.time() - total_start)
    print(f"{counter:03} iterations done in {total_time}s, skipped {skipped}, added {added}\n")

# %%
"""
SYMBOLS = ['ADAUSDT', 'AMBBTC','ARDRUSDT', 'ARDRBTC',
           'BNBUSDT','BNTUSDT', 'BNTBTC', 
           'DOGEUSDT', 'DOTUSDT', 
           'ETCUSDT', 'ETHUSDT', 
           'FUNBTC', 'FUNETH', 'FUNUSDT', 
           'GOBTC',
           'LINKUSDT',
           'MANAUSDT', 'MANABTC', 'MATICUSDT', 'MLNUSDT', 
           'NANOUSDT','NANOBTC',
           'SOLUSDT', 'SUSHIUSDT', 
           'XRPUSDT']
SYMBOLS = ['BTCUSDT', 'DOGEUSDT','FUNBTC','FUNUSDT']
"""
SYMBOLS = ['BTCUSDT', 'ETHUSDT', 'ADAUSDT', 'BNBUSDT', 'XRPUSDT', 'SOLUSDT', 'DOTUSDT', 'DOGEUSDT', 'AVAXUSDT', 'UNIUSDT']


# SYMBOLS = ['BTCUSDT']

startYear = None

for symbol in SYMBOLS:
    if startYear:
        first_year = startYear
    else:
        first_year = datetime.datetime.fromtimestamp(find_first_candlestick(symbol)).year
    print(f"Starting {symbol} in {first_year}")
    for y in range(first_year, 2022):
        load_year(symbol, y)
# Out:
# First Timestamp of BTCUSDT is at 2017-08-17 06:00:00
# Starting BTCUSDT in 2017
# BTCUSDT - 2017
# C:\Users\Crabs\Anaconda3\envs\finrl37\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2017-09-16 09:40:00, rate-limit=1187
#   iteration 086 completed in 15s, avg 2.8 r/sec, next=2017-10-16 06:20:00, rate-limit=1144
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2017-11-15 02:00:00, rate-limit=1101
#   iteration 172 completed in 20s, avg 2.1 r/sec, next=2017-12-14 22:39:20, rate-limit=1058
# 197 iterations done in 80s, skipped 0, added 196544
#
# BTCUSDT - 2018
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2018-01-30 23:45:00, rate-limit=1137
#   iteration 086 completed in 16s, avg 2.6 r/sec, next=2018-03-03 06:44:00, rate-limit=1094
#   iteration 129 completed in 20s, avg 2.1 r/sec, next=2018-04-02 04:24:00, rate-limit=1194
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2018-05-02 01:04:00, rate-limit=1151
#   iteration 215 completed in 16s, avg 2.6 r/sec, next=2018-05-31 21:44:00, rate-limit=1108
#   iteration 258 completed in 22s, avg 1.9 r/sec, next=2018-07-01 06:09:00, rate-limit=1065
#   iteration 301 completed in 16s, avg 2.6 r/sec, next=2018-07-31 10:26:00, rate-limit=1161
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2018-08-30 07:06:00, rate-limit=1118
#   iteration 387 completed in 22s, avg 1.9 r/sec, next=2018-09-29 03:46:00, rate-limit=1075
#   iteration 430 completed in 15s, avg 2.8 r/sec, next=2018-10-29 02:56:00, rate-limit=1169
#   iteration 473 completed in 15s, avg 2.8 r/sec, next=2018-11-28 06:36:00, rate-limit=1126
#   iteration 516 completed in 16s, avg 2.6 r/sec, next=2018-12-28 03:16:00, rate-limit=1083
# 522 iterations done in 216s, skipped 0, added 521624
#
# BTCUSDT - 2019
#   iteration 043 completed in 21s, avg 2.0 r/sec, next=2019-01-30 21:40:00, rate-limit=1183
#   iteration 086 completed in 19s, avg 2.2 r/sec, next=2019-03-01 18:20:00, rate-limit=1140
#   iteration 129 completed in 20s, avg 2.1 r/sec, next=2019-03-31 22:00:00, rate-limit=1097
#   iteration 172 completed in 17s, avg 2.5 r/sec, next=2019-04-30 18:40:00, rate-limit=1184
#   iteration 215 completed in 15s, avg 2.8 r/sec, next=2019-05-31 01:20:00, rate-limit=1141
#   iteration 258 completed in 20s, avg 2.1 r/sec, next=2019-06-29 23:01:00, rate-limit=1098
#   iteration 301 completed in 18s, avg 2.3 r/sec, next=2019-07-29 19:41:00, rate-limit=1199
#   iteration 344 completed in 19s, avg 2.2 r/sec, next=2019-08-29 00:21:00, rate-limit=1156
#   iteration 387 completed in 22s, avg 1.9 r/sec, next=2019-09-27 21:01:00, rate-limit=1113
#   iteration 430 completed in 19s, avg 2.2 r/sec, next=2019-10-27 16:41:00, rate-limit=1194
#   iteration 473 completed in 22s, avg 1.9 r/sec, next=2019-11-26 17:44:00, rate-limit=1151
#   iteration 516 completed in 16s, avg 2.6 r/sec, next=2019-12-26 14:24:00, rate-limit=1108
# 524 iterations done in 238s, skipped 0, added 523836
#
# BTCUSDT - 2020
#   iteration 043 completed in 16s, avg 2.6 r/sec, next=2020-01-30 21:40:00, rate-limit=1198
#   iteration 086 completed in 20s, avg 2.1 r/sec, next=2020-03-01 01:14:00, rate-limit=1155
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2020-03-31 01:02:00, rate-limit=1112
#   iteration 172 completed in 18s, avg 2.3 r/sec, next=2020-04-30 00:12:00, rate-limit=1069
#   iteration 215 completed in 21s, avg 2.0 r/sec, next=2020-05-29 20:52:00, rate-limit=1164
#   iteration 258 completed in 19s, avg 2.2 r/sec, next=2020-06-28 21:02:00, rate-limit=1121
#   iteration 301 completed in 18s, avg 2.3 r/sec, next=2020-07-28 17:42:00, rate-limit=1078
#   iteration 344 completed in 19s, avg 2.2 r/sec, next=2020-08-27 14:22:00, rate-limit=1167
#   iteration 387 completed in 18s, avg 2.3 r/sec, next=2020-09-26 11:02:00, rate-limit=1124
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2020-10-26 06:42:00, rate-limit=1081
#   iteration 473 completed in 20s, avg 2.1 r/sec, next=2020-11-25 03:22:00, rate-limit=1173
#   iteration 516 completed in 17s, avg 2.5 r/sec, next=2020-12-25 05:52:00, rate-limit=1130
# 526 iterations done in 228s, skipped 0, added 525788
#
# BTCUSDT - 2021
#   iteration 043 completed in 22s, avg 1.9 r/sec, next=2021-01-30 21:40:00, rate-limit=1077
#   iteration 086 completed in 20s, avg 2.1 r/sec, next=2021-03-01 19:39:00, rate-limit=1166
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2021-03-31 18:49:00, rate-limit=1123
#   iteration 172 completed in 20s, avg 2.1 r/sec, next=2021-04-30 22:43:00, rate-limit=1080
#   iteration 215 completed in 19s, avg 2.2 r/sec, next=2021-05-30 19:23:00, rate-limit=1169
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2021-06-29 16:03:00, rate-limit=1126
#   iteration 301 completed in 19s, avg 2.2 r/sec, next=2021-07-29 12:43:00, rate-limit=1083
#   iteration 344 completed in 17s, avg 2.5 r/sec, next=2021-08-28 13:53:00, rate-limit=1184
#   iteration 387 completed in 18s, avg 2.3 r/sec, next=2021-09-27 10:33:00, rate-limit=1141
#   iteration 430 completed in 20s, avg 2.1 r/sec, next=2021-10-27 09:13:00, rate-limit=1098
#   iteration 473 completed in 17s, avg 2.5 r/sec, next=2021-11-26 04:53:00, rate-limit=1191
#   iteration 516 completed in 17s, avg 2.5 r/sec, next=2021-12-26 01:33:00, rate-limit=1148
# 525 iterations done in 229s, skipped 0, added 524607
#
# First Timestamp of ETHUSDT is at 2017-08-17 06:00:00
# Starting ETHUSDT in 2017
# ETHUSDT - 2017
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2017-09-16 09:40:00, rate-limit=1095
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2017-10-16 06:20:00, rate-limit=1052
#   iteration 129 completed in 19s, avg 2.2 r/sec, next=2017-11-15 02:00:00, rate-limit=1160
#   iteration 172 completed in 19s, avg 2.2 r/sec, next=2017-12-14 22:39:20, rate-limit=1117
# 197 iterations done in 84s, skipped 0, added 196544
#
# ETHUSDT - 2018
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2018-01-30 23:45:00, rate-limit=1187
#   iteration 086 completed in 21s, avg 2.0 r/sec, next=2018-03-03 06:44:00, rate-limit=1144
#   iteration 129 completed in 20s, avg 2.1 r/sec, next=2018-04-02 04:24:00, rate-limit=1101
#   iteration 172 completed in 20s, avg 2.1 r/sec, next=2018-05-02 01:04:00, rate-limit=1185
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2018-05-31 21:44:00, rate-limit=1142
#   iteration 258 completed in 20s, avg 2.1 r/sec, next=2018-07-01 06:09:00, rate-limit=1099
#   iteration 301 completed in 20s, avg 2.1 r/sec, next=2018-07-31 10:26:00, rate-limit=1184
#   iteration 344 completed in 19s, avg 2.2 r/sec, next=2018-08-30 07:06:00, rate-limit=1141
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2018-09-29 03:46:00, rate-limit=1098
#   iteration 430 completed in 17s, avg 2.5 r/sec, next=2018-10-29 02:56:00, rate-limit=1193
#   iteration 473 completed in 20s, avg 2.1 r/sec, next=2018-11-28 06:36:00, rate-limit=1150
#   iteration 516 completed in 19s, avg 2.2 r/sec, next=2018-12-28 03:16:00, rate-limit=1107
# 522 iterations done in 235s, skipped 0, added 521624
#
# ETHUSDT - 2019
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2019-01-30 21:40:00, rate-limit=1195
#   iteration 086 completed in 25s, avg 1.7 r/sec, next=2019-03-01 18:20:00, rate-limit=1152
#   iteration 129 completed in 18s, avg 2.3 r/sec, next=2019-03-31 22:00:00, rate-limit=1109
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2019-04-30 18:40:00, rate-limit=1194
#   iteration 215 completed in 14s, avg 3.0 r/sec, next=2019-05-31 01:20:00, rate-limit=1151
#   iteration 258 completed in 15s, avg 2.8 r/sec, next=2019-06-29 23:01:00, rate-limit=1108
#   iteration 301 completed in 15s, avg 2.8 r/sec, next=2019-07-29 19:41:00, rate-limit=1065
#   iteration 344 completed in 22s, avg 1.9 r/sec, next=2019-08-29 00:21:00, rate-limit=1176
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2019-09-27 21:01:00, rate-limit=1133
#   iteration 430 completed in 14s, avg 3.0 r/sec, next=2019-10-27 16:41:00, rate-limit=1090
#   iteration 473 completed in 19s, avg 2.2 r/sec, next=2019-11-26 17:44:00, rate-limit=1198
#   iteration 516 completed in 17s, avg 2.5 r/sec, next=2019-12-26 14:24:00, rate-limit=1155
# 524 iterations done in 218s, skipped 0, added 523836
#
# ETHUSDT - 2020
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2020-01-30 21:40:00, rate-limit=1104
#   iteration 086 completed in 21s, avg 2.0 r/sec, next=2020-03-01 01:14:00, rate-limit=1196
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2020-03-31 01:02:00, rate-limit=1153
#   iteration 172 completed in 14s, avg 3.0 r/sec, next=2020-04-30 00:12:00, rate-limit=1110
#   iteration 215 completed in 23s, avg 1.8 r/sec, next=2020-05-29 20:52:00, rate-limit=1067
#   iteration 258 completed in 16s, avg 2.6 r/sec, next=2020-06-28 21:02:00, rate-limit=1164
#   iteration 301 completed in 17s, avg 2.5 r/sec, next=2020-07-28 17:42:00, rate-limit=1121
#   iteration 344 completed in 21s, avg 2.0 r/sec, next=2020-08-27 14:22:00, rate-limit=1078
#   iteration 387 completed in 19s, avg 2.2 r/sec, next=2020-09-26 11:02:00, rate-limit=1172
#   iteration 430 completed in 17s, avg 2.5 r/sec, next=2020-10-26 06:42:00, rate-limit=1129
#   iteration 473 completed in 18s, avg 2.3 r/sec, next=2020-11-25 03:22:00, rate-limit=1086
#   iteration 516 completed in 16s, avg 2.6 r/sec, next=2020-12-25 05:53:00, rate-limit=1184
# 526 iterations done in 226s, skipped 0, added 525787
#
# ETHUSDT - 2021
#   iteration 043 completed in 23s, avg 1.8 r/sec, next=2021-01-30 21:40:00, rate-limit=1131
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2021-03-01 19:39:00, rate-limit=1088
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2021-03-31 18:49:00, rate-limit=1182
#   iteration 172 completed in 21s, avg 2.0 r/sec, next=2021-04-30 22:43:00, rate-limit=1139
#   iteration 215 completed in 17s, avg 2.5 r/sec, next=2021-05-30 19:23:00, rate-limit=1096
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2021-06-29 16:03:00, rate-limit=1193
#   iteration 301 completed in 14s, avg 3.0 r/sec, next=2021-07-29 12:43:00, rate-limit=1150
#   iteration 344 completed in 18s, avg 2.3 r/sec, next=2021-08-28 13:53:00, rate-limit=1107
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2021-09-27 10:33:00, rate-limit=1064
#   iteration 430 completed in 19s, avg 2.2 r/sec, next=2021-10-27 09:13:00, rate-limit=1174
#   iteration 473 completed in 21s, avg 2.0 r/sec, next=2021-11-26 04:53:00, rate-limit=1131
#   iteration 516 completed in 19s, avg 2.2 r/sec, next=2021-12-26 01:33:00, rate-limit=1088
# 525 iterations done in 230s, skipped 0, added 524607
#
# First Timestamp of ADAUSDT is at 2018-04-17 06:02:00
# Starting ADAUSDT in 2018
# ADAUSDT - 2018
#   iteration 043 completed in 19s, avg 2.2 r/sec, next=2018-05-17 02:42:00, rate-limit=1158
#   iteration 086 completed in 14s, avg 3.0 r/sec, next=2018-06-15 23:22:00, rate-limit=1115
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2018-07-16 15:24:00, rate-limit=1072
#   iteration 172 completed in 14s, avg 3.0 r/sec, next=2018-08-15 12:04:00, rate-limit=1192
#   iteration 215 completed in 19s, avg 2.2 r/sec, next=2018-09-14 08:44:00, rate-limit=1149
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2018-10-14 05:24:00, rate-limit=1106
#   iteration 301 completed in 17s, avg 2.5 r/sec, next=2018-11-13 04:34:00, rate-limit=1063
#   iteration 344 completed in 15s, avg 2.8 r/sec, next=2018-12-13 08:14:00, rate-limit=1161
# 371 iterations done in 144s, skipped 0, added 370926
#
# ADAUSDT - 2019
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2019-01-30 21:40:00, rate-limit=1091
#   iteration 086 completed in 15s, avg 2.8 r/sec, next=2019-03-01 18:20:00, rate-limit=1048
#   iteration 129 completed in 19s, avg 2.2 r/sec, next=2019-03-31 22:00:00, rate-limit=1169
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2019-04-30 18:40:00, rate-limit=1126
#   iteration 215 completed in 15s, avg 2.8 r/sec, next=2019-05-31 01:20:00, rate-limit=1083
#   iteration 258 completed in 23s, avg 1.8 r/sec, next=2019-06-29 23:01:00, rate-limit=1177
#   iteration 301 completed in 15s, avg 2.8 r/sec, next=2019-07-29 19:41:00, rate-limit=1134
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2019-08-29 00:21:00, rate-limit=1091
#   iteration 387 completed in 14s, avg 3.0 r/sec, next=2019-09-27 21:01:00, rate-limit=1048
#   iteration 430 completed in 14s, avg 3.0 r/sec, next=2019-10-27 16:41:00, rate-limit=1165
#   iteration 473 completed in 17s, avg 2.5 r/sec, next=2019-11-26 17:44:00, rate-limit=1122
#   iteration 516 completed in 16s, avg 2.6 r/sec, next=2019-12-26 14:24:00, rate-limit=1079
# 524 iterations done in 206s, skipped 0, added 523836
#
# ADAUSDT - 2020
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2020-01-30 21:40:00, rate-limit=1181
#   iteration 086 completed in 16s, avg 2.6 r/sec, next=2020-03-01 01:14:00, rate-limit=1138
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2020-03-31 01:02:00, rate-limit=1095
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2020-04-30 00:12:00, rate-limit=1052
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2020-05-29 20:52:00, rate-limit=1165
#   iteration 258 completed in 14s, avg 3.0 r/sec, next=2020-06-28 21:02:00, rate-limit=1122
#   iteration 301 completed in 22s, avg 1.9 r/sec, next=2020-07-28 17:42:00, rate-limit=1079
#   iteration 344 completed in 18s, avg 2.3 r/sec, next=2020-08-27 14:22:00, rate-limit=1173
#   iteration 387 completed in 20s, avg 2.1 r/sec, next=2020-09-26 11:02:00, rate-limit=1130
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2020-10-26 06:42:00, rate-limit=1087
#   iteration 473 completed in 18s, avg 2.3 r/sec, next=2020-11-25 03:22:00, rate-limit=1187
#   iteration 516 completed in 18s, avg 2.3 r/sec, next=2020-12-25 05:53:00, rate-limit=1144
# 526 iterations done in 222s, skipped 0, added 525787
#
# ADAUSDT - 2021
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2021-01-30 21:40:00, rate-limit=1091
#   iteration 086 completed in 16s, avg 2.6 r/sec, next=2021-03-01 19:39:00, rate-limit=1180
#   iteration 129 completed in 22s, avg 1.9 r/sec, next=2021-03-31 18:49:00, rate-limit=1137
#   iteration 172 completed in 19s, avg 2.2 r/sec, next=2021-04-30 22:43:00, rate-limit=1094
#   iteration 215 completed in 17s, avg 2.5 r/sec, next=2021-05-30 19:23:00, rate-limit=1180
#   iteration 258 completed in 21s, avg 2.0 r/sec, next=2021-06-29 16:03:00, rate-limit=1137
#   iteration 301 completed in 15s, avg 2.8 r/sec, next=2021-07-29 12:43:00, rate-limit=1094
#   iteration 344 completed in 18s, avg 2.3 r/sec, next=2021-08-28 13:53:00, rate-limit=1190
#   iteration 387 completed in 18s, avg 2.3 r/sec, next=2021-09-27 10:33:00, rate-limit=1147
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2021-10-27 09:13:00, rate-limit=1104
#   iteration 473 completed in 14s, avg 3.0 r/sec, next=2021-11-26 04:53:00, rate-limit=1061
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2021-12-26 01:33:00, rate-limit=1179
# 525 iterations done in 219s, skipped 0, added 524607
#
# First Timestamp of BNBUSDT is at 2017-11-06 04:54:00
# Starting BNBUSDT in 2017
# BNBUSDT - 2017
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2017-12-06 01:33:21, rate-limit=1126
# 081 iterations done in 29s, skipped 0, added 80330
#
# BNBUSDT - 2018
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2018-01-30 23:45:00, rate-limit=1045
#   iteration 086 completed in 18s, avg 2.3 r/sec, next=2018-03-03 06:44:00, rate-limit=1163
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2018-04-02 04:24:00, rate-limit=1120
#   iteration 172 completed in 14s, avg 3.0 r/sec, next=2018-05-02 01:04:00, rate-limit=1077
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2018-05-31 21:44:00, rate-limit=1187
#   iteration 258 completed in 18s, avg 2.3 r/sec, next=2018-07-01 06:09:00, rate-limit=1144
#   iteration 301 completed in 14s, avg 3.0 r/sec, next=2018-07-31 10:26:00, rate-limit=1101
#   iteration 344 completed in 14s, avg 3.0 r/sec, next=2018-08-30 07:06:00, rate-limit=1058
#   iteration 387 completed in 18s, avg 2.3 r/sec, next=2018-09-29 03:46:00, rate-limit=1170
#   iteration 430 completed in 15s, avg 2.8 r/sec, next=2018-10-29 02:56:00, rate-limit=1127
#   iteration 473 completed in 15s, avg 2.8 r/sec, next=2018-11-28 06:36:00, rate-limit=1084
#   iteration 516 completed in 16s, avg 2.6 r/sec, next=2018-12-28 03:16:00, rate-limit=1041
# 522 iterations done in 199s, skipped 0, added 521624
#
# BNBUSDT - 2019
#   iteration 043 completed in 16s, avg 2.6 r/sec, next=2019-01-30 21:40:00, rate-limit=1151
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2019-03-01 18:20:00, rate-limit=1108
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2019-03-31 22:00:00, rate-limit=1065
#   iteration 172 completed in 20s, avg 2.1 r/sec, next=2019-04-30 18:40:00, rate-limit=1174
#   iteration 215 completed in 19s, avg 2.2 r/sec, next=2019-05-31 01:20:00, rate-limit=1131
#   iteration 258 completed in 15s, avg 2.8 r/sec, next=2019-06-29 23:01:00, rate-limit=1088
#   iteration 301 completed in 20s, avg 2.1 r/sec, next=2019-07-29 19:41:00, rate-limit=1186
#   iteration 344 completed in 17s, avg 2.5 r/sec, next=2019-08-29 00:21:00, rate-limit=1143
#   iteration 387 completed in 16s, avg 2.6 r/sec, next=2019-09-27 21:01:00, rate-limit=1100
#   iteration 430 completed in 14s, avg 3.0 r/sec, next=2019-10-27 16:41:00, rate-limit=1057
#   iteration 473 completed in 18s, avg 2.3 r/sec, next=2019-11-26 17:44:00, rate-limit=1165
#   iteration 516 completed in 14s, avg 3.0 r/sec, next=2019-12-26 14:24:00, rate-limit=1122
# 524 iterations done in 210s, skipped 0, added 523836
#
# BNBUSDT - 2020
#   iteration 043 completed in 20s, avg 2.1 r/sec, next=2020-01-30 21:40:00, rate-limit=1071
#   iteration 086 completed in 19s, avg 2.2 r/sec, next=2020-03-01 01:14:00, rate-limit=1174
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2020-03-31 01:02:00, rate-limit=1131
#   iteration 172 completed in 19s, avg 2.2 r/sec, next=2020-04-30 00:12:00, rate-limit=1088
#   iteration 215 completed in 20s, avg 2.1 r/sec, next=2020-05-29 20:52:00, rate-limit=1178
#   iteration 258 completed in 16s, avg 2.6 r/sec, next=2020-06-28 21:02:00, rate-limit=1135
#   iteration 301 completed in 19s, avg 2.2 r/sec, next=2020-07-28 17:42:00, rate-limit=1092
#   iteration 344 completed in 18s, avg 2.3 r/sec, next=2020-08-27 14:22:00, rate-limit=1197
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2020-09-26 11:02:00, rate-limit=1154
#   iteration 430 completed in 15s, avg 2.8 r/sec, next=2020-10-26 06:42:00, rate-limit=1111
#   iteration 473 completed in 20s, avg 2.1 r/sec, next=2020-11-25 03:22:00, rate-limit=1068
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2020-12-25 05:53:00, rate-limit=1172
# 526 iterations done in 222s, skipped 0, added 525787
#
# BNBUSDT - 2021
#   iteration 043 completed in 19s, avg 2.2 r/sec, next=2021-01-30 21:40:00, rate-limit=1119
#   iteration 086 completed in 20s, avg 2.1 r/sec, next=2021-03-01 19:39:00, rate-limit=1076
#   iteration 129 completed in 18s, avg 2.3 r/sec, next=2021-03-31 18:49:00, rate-limit=1167
#   iteration 172 completed in 18s, avg 2.3 r/sec, next=2021-04-30 22:43:00, rate-limit=1124
#   iteration 215 completed in 19s, avg 2.2 r/sec, next=2021-05-30 19:23:00, rate-limit=1081
#   iteration 258 completed in 16s, avg 2.6 r/sec, next=2021-06-29 16:03:00, rate-limit=1181
#   iteration 301 completed in 17s, avg 2.5 r/sec, next=2021-07-29 12:43:00, rate-limit=1138
#   iteration 344 completed in 21s, avg 2.0 r/sec, next=2021-08-28 13:53:00, rate-limit=1095
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2021-09-27 10:33:00, rate-limit=1193
#   iteration 430 completed in 14s, avg 3.0 r/sec, next=2021-10-27 09:13:00, rate-limit=1150
#   iteration 473 completed in 20s, avg 2.1 r/sec, next=2021-11-26 04:53:00, rate-limit=1107
#   iteration 516 completed in 18s, avg 2.3 r/sec, next=2021-12-26 01:33:00, rate-limit=1064
# 525 iterations done in 225s, skipped 0, added 524607
#
# First Timestamp of XRPUSDT is at 2018-05-04 10:11:00
# Starting XRPUSDT in 2018
# XRPUSDT - 2018
#   iteration 043 completed in 16s, avg 2.6 r/sec, next=2018-06-03 06:51:00, rate-limit=1156
#   iteration 086 completed in 20s, avg 2.1 r/sec, next=2018-07-03 15:16:00, rate-limit=1113
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2018-08-02 19:33:00, rate-limit=1070
#   iteration 172 completed in 15s, avg 2.8 r/sec, next=2018-09-01 16:13:00, rate-limit=1168
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2018-10-01 12:53:00, rate-limit=1125
#   iteration 258 completed in 18s, avg 2.3 r/sec, next=2018-10-31 12:03:00, rate-limit=1082
#   iteration 301 completed in 16s, avg 2.6 r/sec, next=2018-11-30 15:43:00, rate-limit=1185
#   iteration 344 completed in 21s, avg 2.0 r/sec, next=2018-12-30 12:23:00, rate-limit=1142
# 347 iterations done in 147s, skipped 0, added 346197
#
# XRPUSDT - 2019
#   iteration 043 completed in 16s, avg 2.6 r/sec, next=2019-01-30 21:40:00, rate-limit=1096
#   iteration 086 completed in 15s, avg 2.8 r/sec, next=2019-03-01 18:20:00, rate-limit=1196
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2019-03-31 22:00:00, rate-limit=1153
#   iteration 172 completed in 19s, avg 2.2 r/sec, next=2019-04-30 18:40:00, rate-limit=1110
#   iteration 215 completed in 17s, avg 2.5 r/sec, next=2019-05-31 01:20:00, rate-limit=1067
#   iteration 258 completed in 20s, avg 2.1 r/sec, next=2019-06-29 23:01:00, rate-limit=1168
#   iteration 301 completed in 20s, avg 2.1 r/sec, next=2019-07-29 19:41:00, rate-limit=1125
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2019-08-29 00:21:00, rate-limit=1082
#   iteration 387 completed in 15s, avg 2.8 r/sec, next=2019-09-27 21:01:00, rate-limit=1178
#   iteration 430 completed in 19s, avg 2.2 r/sec, next=2019-10-27 16:41:00, rate-limit=1135
#   iteration 473 completed in 15s, avg 2.8 r/sec, next=2019-11-26 17:44:00, rate-limit=1092
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2019-12-26 14:24:00, rate-limit=1049
# 524 iterations done in 212s, skipped 0, added 523836
#
# XRPUSDT - 2020
#   iteration 043 completed in 16s, avg 2.6 r/sec, next=2020-01-30 21:40:00, rate-limit=1154
#   iteration 086 completed in 18s, avg 2.3 r/sec, next=2020-03-01 01:14:00, rate-limit=1111
#   iteration 129 completed in 19s, avg 2.2 r/sec, next=2020-03-31 01:02:00, rate-limit=1068
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2020-04-30 00:12:00, rate-limit=1172
#   iteration 215 completed in 15s, avg 2.8 r/sec, next=2020-05-29 20:52:00, rate-limit=1129
#   iteration 258 completed in 14s, avg 3.0 r/sec, next=2020-06-28 21:02:00, rate-limit=1086
#   iteration 301 completed in 19s, avg 2.2 r/sec, next=2020-07-28 17:42:00, rate-limit=1043
#   iteration 344 completed in 19s, avg 2.2 r/sec, next=2020-08-27 14:22:00, rate-limit=1157
#   iteration 387 completed in 15s, avg 2.8 r/sec, next=2020-09-26 11:02:00, rate-limit=1114
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2020-10-26 06:42:00, rate-limit=1071
#   iteration 473 completed in 19s, avg 2.2 r/sec, next=2020-11-25 03:22:00, rate-limit=1173
#   iteration 516 completed in 20s, avg 2.1 r/sec, next=2020-12-25 05:53:00, rate-limit=1130
# 526 iterations done in 215s, skipped 0, added 525787
#
# XRPUSDT - 2021
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2021-01-30 21:40:00, rate-limit=1077
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2021-03-01 19:39:00, rate-limit=1170
#   iteration 129 completed in 18s, avg 2.3 r/sec, next=2021-03-31 18:49:00, rate-limit=1127
#   iteration 172 completed in 15s, avg 2.8 r/sec, next=2021-04-30 22:42:00, rate-limit=1084
#   iteration 215 completed in 21s, avg 2.0 r/sec, next=2021-05-30 19:22:00, rate-limit=1183
#   iteration 258 completed in 15s, avg 2.8 r/sec, next=2021-06-29 16:02:00, rate-limit=1140
#   iteration 301 completed in 18s, avg 2.3 r/sec, next=2021-07-29 12:42:00, rate-limit=1097
#   iteration 344 completed in 17s, avg 2.5 r/sec, next=2021-08-28 13:52:00, rate-limit=1198
#   iteration 387 completed in 14s, avg 3.0 r/sec, next=2021-09-27 10:32:00, rate-limit=1155
#   iteration 430 completed in 17s, avg 2.5 r/sec, next=2021-10-27 09:12:00, rate-limit=1112
#   iteration 473 completed in 18s, avg 2.3 r/sec, next=2021-11-26 04:52:00, rate-limit=1069
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2021-12-26 01:32:00, rate-limit=1184
# 525 iterations done in 213s, skipped 0, added 524608
#
# First Timestamp of SOLUSDT is at 2020-08-11 08:00:00
# Starting SOLUSDT in 2020
# SOLUSDT - 2020
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2020-09-10 04:40:00, rate-limit=1131
#   iteration 086 completed in 16s, avg 2.6 r/sec, next=2020-10-10 01:20:00, rate-limit=1088
#   iteration 129 completed in 18s, avg 2.3 r/sec, next=2020-11-08 21:00:00, rate-limit=1045
#   iteration 172 completed in 15s, avg 2.8 r/sec, next=2020-12-08 18:40:00, rate-limit=1158
# 206 iterations done in 78s, skipped 0, added 205209
#
# SOLUSDT - 2021
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2021-01-30 21:40:00, rate-limit=1081
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2021-03-01 19:39:00, rate-limit=1191
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2021-03-31 18:49:00, rate-limit=1148
#   iteration 172 completed in 21s, avg 2.0 r/sec, next=2021-04-30 22:43:00, rate-limit=1105
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2021-05-30 19:23:00, rate-limit=1198
#   iteration 258 completed in 18s, avg 2.3 r/sec, next=2021-06-29 16:03:00, rate-limit=1155
#   iteration 301 completed in 20s, avg 2.1 r/sec, next=2021-07-29 12:43:00, rate-limit=1112
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2021-08-28 13:53:00, rate-limit=1069
#   iteration 387 completed in 15s, avg 2.8 r/sec, next=2021-09-27 10:33:00, rate-limit=1165
#   iteration 430 completed in 19s, avg 2.2 r/sec, next=2021-10-27 09:13:00, rate-limit=1122
#   iteration 473 completed in 19s, avg 2.2 r/sec, next=2021-11-26 04:53:00, rate-limit=1079
#   iteration 516 completed in 17s, avg 2.5 r/sec, next=2021-12-26 01:33:00, rate-limit=1178
# 525 iterations done in 224s, skipped 0, added 524607
#
# First Timestamp of DOTUSDT is at 2020-08-19 01:00:00
# Starting DOTUSDT in 2020
# DOTUSDT - 2020
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2020-09-17 21:40:00, rate-limit=1125
#   iteration 086 completed in 18s, avg 2.3 r/sec, next=2020-10-17 18:20:00, rate-limit=1082
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2020-11-16 14:00:00, rate-limit=1188
#   iteration 172 completed in 19s, avg 2.2 r/sec, next=2020-12-16 11:40:00, rate-limit=1145
# 195 iterations done in 79s, skipped 0, added 194109
#
# DOTUSDT - 2021
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2021-01-30 21:40:00, rate-limit=1079
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2021-03-01 19:39:00, rate-limit=1181
#   iteration 129 completed in 38s, avg 1.1 r/sec, next=2021-03-31 18:49:00, rate-limit=1138
#   iteration 172 completed in 15s, avg 2.8 r/sec, next=2021-04-30 22:43:00, rate-limit=1195
#   iteration 215 completed in 21s, avg 2.0 r/sec, next=2021-05-30 19:23:00, rate-limit=1152
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2021-06-29 16:03:00, rate-limit=1109
#   iteration 301 completed in 15s, avg 2.8 r/sec, next=2021-07-29 12:43:00, rate-limit=1066
#   iteration 344 completed in 19s, avg 2.2 r/sec, next=2021-08-28 13:53:00, rate-limit=1160
#   iteration 387 completed in 15s, avg 2.8 r/sec, next=2021-09-27 10:33:00, rate-limit=1117
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2021-10-27 09:13:00, rate-limit=1074
#   iteration 473 completed in 17s, avg 2.5 r/sec, next=2021-11-26 04:53:00, rate-limit=1183
#   iteration 516 completed in 16s, avg 2.6 r/sec, next=2021-12-26 01:33:00, rate-limit=1140
# 525 iterations done in 234s, skipped 0, added 524607
#
# First Timestamp of DOGEUSDT is at 2019-07-05 14:00:00
# Starting DOGEUSDT in 2019
# DOGEUSDT - 2019
#   iteration 043 completed in 13s, avg 3.3 r/sec, next=2019-08-04 10:40:00, rate-limit=1087
#   iteration 086 completed in 20s, avg 2.1 r/sec, next=2019-09-03 15:20:00, rate-limit=1196
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2019-10-03 12:00:00, rate-limit=1153
#   iteration 172 completed in 15s, avg 2.8 r/sec, next=2019-11-02 07:40:00, rate-limit=1110
#   iteration 215 completed in 14s, avg 3.0 r/sec, next=2019-12-02 08:43:00, rate-limit=1067
#   iteration 258 completed in 14s, avg 3.0 r/sec, next=2020-01-01 01:00:00, rate-limit=1197
# 258 iterations done in 93s, skipped 0, added 257737
#
# DOGEUSDT - 2020
#   iteration 043 completed in 13s, avg 3.3 r/sec, next=2020-01-30 21:40:00, rate-limit=1154
#   iteration 086 completed in 14s, avg 3.0 r/sec, next=2020-03-01 01:14:00, rate-limit=1111
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2020-03-31 01:02:00, rate-limit=1068
#   iteration 172 completed in 17s, avg 2.5 r/sec, next=2020-04-30 00:12:00, rate-limit=1193
#   iteration 215 completed in 13s, avg 3.3 r/sec, next=2020-05-29 20:52:00, rate-limit=1150
#   iteration 258 completed in 16s, avg 2.6 r/sec, next=2020-06-28 21:02:00, rate-limit=1107
#   iteration 301 completed in 18s, avg 2.3 r/sec, next=2020-07-28 17:42:00, rate-limit=1064
#   iteration 344 completed in 15s, avg 2.8 r/sec, next=2020-08-27 14:22:00, rate-limit=1179
#   iteration 387 completed in 15s, avg 2.8 r/sec, next=2020-09-26 11:02:00, rate-limit=1136
#   iteration 430 completed in 17s, avg 2.5 r/sec, next=2020-10-26 06:42:00, rate-limit=1093
#   iteration 473 completed in 14s, avg 3.0 r/sec, next=2020-11-25 03:22:00, rate-limit=1050
#   iteration 516 completed in 14s, avg 3.0 r/sec, next=2020-12-25 05:53:00, rate-limit=1166
# 526 iterations done in 194s, skipped 0, added 525787
#
# DOGEUSDT - 2021
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2021-01-30 21:40:00, rate-limit=1113
#   iteration 086 completed in 19s, avg 2.2 r/sec, next=2021-03-01 19:39:00, rate-limit=1070
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2021-03-31 18:49:00, rate-limit=1179
#   iteration 172 completed in 22s, avg 1.9 r/sec, next=2021-04-30 22:43:00, rate-limit=1136
#   iteration 215 completed in 17s, avg 2.5 r/sec, next=2021-05-30 19:23:00, rate-limit=1093
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2021-06-29 16:03:00, rate-limit=1190
#   iteration 301 completed in 19s, avg 2.2 r/sec, next=2021-07-29 12:43:00, rate-limit=1147
#   iteration 344 completed in 15s, avg 2.8 r/sec, next=2021-08-28 13:53:00, rate-limit=1104
#   iteration 387 completed in 16s, avg 2.6 r/sec, next=2021-09-27 10:33:00, rate-limit=1061
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2021-10-27 09:13:00, rate-limit=1171
#   iteration 473 completed in 18s, avg 2.3 r/sec, next=2021-11-26 04:53:00, rate-limit=1128
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2021-12-26 01:33:00, rate-limit=1085
# 525 iterations done in 213s, skipped 0, added 524607
#
# First Timestamp of AVAXUSDT is at 2020-09-22 08:30:00
# Starting AVAXUSDT in 2020
# AVAXUSDT - 2020
#   iteration 043 completed in 14s, avg 3.0 r/sec, next=2020-10-22 05:10:00, rate-limit=1190
#   iteration 086 completed in 16s, avg 2.6 r/sec, next=2020-11-21 00:50:00, rate-limit=1147
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2020-12-20 22:30:00, rate-limit=1104
# 145 iterations done in 51s, skipped 0, added 144699
#
# AVAXUSDT - 2021
#   iteration 043 completed in 16s, avg 2.6 r/sec, next=2021-01-30 21:40:00, rate-limit=1045
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2021-03-01 19:39:00, rate-limit=1163
#   iteration 129 completed in 21s, avg 2.0 r/sec, next=2021-03-31 18:49:00, rate-limit=1120
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2021-04-30 22:43:00, rate-limit=1077
#   iteration 215 completed in 15s, avg 2.8 r/sec, next=2021-05-30 19:23:00, rate-limit=1176
#   iteration 258 completed in 15s, avg 2.8 r/sec, next=2021-06-29 16:03:00, rate-limit=1133
#   iteration 301 completed in 15s, avg 2.8 r/sec, next=2021-07-29 12:43:00, rate-limit=1090
#   iteration 344 completed in 19s, avg 2.2 r/sec, next=2021-08-28 13:53:00, rate-limit=1047
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2021-09-27 10:33:00, rate-limit=1157
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2021-10-27 09:13:00, rate-limit=1114
#   iteration 473 completed in 16s, avg 2.6 r/sec, next=2021-11-26 04:53:00, rate-limit=1071
#   iteration 516 completed in 19s, avg 2.2 r/sec, next=2021-12-26 01:33:00, rate-limit=1171
# 525 iterations done in 213s, skipped 0, added 524607
#
# First Timestamp of UNIUSDT is at 2020-09-17 05:00:00
# Starting UNIUSDT in 2020
# UNIUSDT - 2020
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2020-10-17 01:40:00, rate-limit=1118
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2020-11-15 21:20:00, rate-limit=1075
#   iteration 129 completed in 19s, avg 2.2 r/sec, next=2020-12-15 19:00:00, rate-limit=1182
# 153 iterations done in 64s, skipped 0, added 152109
#
# UNIUSDT - 2021
#   iteration 043 completed in 20s, avg 2.1 r/sec, next=2021-01-30 21:40:00, rate-limit=1115
#   iteration 086 completed in 22s, avg 1.9 r/sec, next=2021-03-01 19:39:00, rate-limit=1194
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2021-03-31 18:49:00, rate-limit=1151
#   iteration 172 completed in 22s, avg 1.9 r/sec, next=2021-04-30 22:43:00, rate-limit=1108
#   iteration 215 completed in 20s, avg 2.1 r/sec, next=2021-05-30 19:23:00, rate-limit=1196
#   iteration 258 completed in 15s, avg 2.8 r/sec, next=2021-06-29 16:03:00, rate-limit=1153
#   iteration 301 completed in 19s, avg 2.2 r/sec, next=2021-07-29 12:43:00, rate-limit=1110
#   iteration 344 completed in 17s, avg 2.5 r/sec, next=2021-08-28 13:53:00, rate-limit=1067
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2021-09-27 10:33:00, rate-limit=1168
#   iteration 430 completed in 14s, avg 3.0 r/sec, next=2021-10-27 09:13:00, rate-limit=1125
#   iteration 473 completed in 17s, avg 2.5 r/sec, next=2021-11-26 04:53:00, rate-limit=1082
#   iteration 516 completed in 14s, avg 3.0 r/sec, next=2021-12-26 01:33:00, rate-limit=1039
# 525 iterations done in 223s, skipped 0, added 524607

# %%
SYMBOLS = ['BTCUSDT', 'ETHUSDT', 'ADAUSDT', 'BNBUSDT', 'XRPUSDT', 'SOLUSDT', 'DOTUSDT', 'DOGEUSDT', 'AVAXUSDT', 'UNIUSDT']
# SYMBOLS = ['BTCUSDT']
for symbol in SYMBOLS:
    # first_year = datetime.datetime.fromtimestamp(find_first_candlestick(symbol)).year
    for y in range(2022, 2023):
        load_year(symbol, y)

# %%
SYMBOLS = ['NEOUSDT', 'LTCUSDT', 'EOSUSDT', 'XLMUSDT', 'SHIBUSDT', 'IOTAUSDT', 'TRXUSDT', 'ETCUSDT', 'LINKUSDT', 'XMRUSDT', 'MATICUSDT', 'ALGOUSDT', 'MANAUSDT']

# %%
# SYMBOLS = ['BTCUSDT', 'ETHUSDT', 'ADAUSDT', 'BNBUSDT', 'XRPUSDT', 'SOLUSDT', 'DOTUSDT', 'DOGEUSDT', 'AVAXUSDT', 'UNIUSDT']
SYMBOLS = ['LTCUSDT', 'EOSUSDT', 'XLMUSDT', 'SHIBUSDT']
# SYMBOLS = ['BTCUSDT']
for symbol in SYMBOLS:
    first_year = datetime.datetime.fromtimestamp(find_first_candlestick(symbol)).year
    for y in range(first_year, 2023):
        load_year(symbol, y)
# Out:
# First Timestamp of LTCUSDT is at 2017-12-13 04:32:00
# LTCUSDT - 2017
# C:\Users\Crabs\Anaconda3\envs\finrl37\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 028 iterations done in 9s, skipped 0, added 27071
#
# LTCUSDT - 2018
#   iteration 043 completed in 20s, avg 2.1 r/sec, next=2018-01-30 23:45:00, rate-limit=1039
#   iteration 086 completed in 16s, avg 2.6 r/sec, next=2018-03-03 06:45:00, rate-limit=906
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2018-04-02 04:25:00, rate-limit=1142
#   iteration 172 completed in 21s, avg 2.0 r/sec, next=2018-05-02 01:05:00, rate-limit=1000
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2018-05-31 21:45:00, rate-limit=862
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2018-07-01 06:10:00, rate-limit=1177
#   iteration 301 completed in 20s, avg 2.1 r/sec, next=2018-07-31 10:27:00, rate-limit=1043
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2018-08-30 07:07:00, rate-limit=923
#   iteration 387 completed in 19s, avg 2.2 r/sec, next=2018-09-29 03:47:00, rate-limit=1198
#   iteration 430 completed in 18s, avg 2.3 r/sec, next=2018-10-29 02:57:00, rate-limit=1051
#   iteration 473 completed in 19s, avg 2.2 r/sec, next=2018-11-28 06:37:00, rate-limit=900
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2018-12-28 03:17:00, rate-limit=773
# 522 iterations done in 224s, skipped 0, added 521623
#
# LTCUSDT - 2019
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2019-01-30 21:40:00, rate-limit=1096
#   iteration 086 completed in 17s, avg 2.5 r/sec, next=2019-03-01 18:20:00, rate-limit=951
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2019-03-31 22:00:00, rate-limit=819
#   iteration 172 completed in 18s, avg 2.3 r/sec, next=2019-04-30 18:40:00, rate-limit=1167
#   iteration 215 completed in 16s, avg 2.6 r/sec, next=2019-05-31 01:20:00, rate-limit=1038
#   iteration 258 completed in 14s, avg 3.0 r/sec, next=2019-06-29 23:01:00, rate-limit=910
#   iteration 301 completed in 16s, avg 2.6 r/sec, next=2019-07-29 19:41:00, rate-limit=787
#   iteration 344 completed in 18s, avg 2.3 r/sec, next=2019-08-29 00:21:00, rate-limit=1103
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2019-09-27 21:01:00, rate-limit=980
#   iteration 430 completed in 15s, avg 2.8 r/sec, next=2019-10-27 16:41:00, rate-limit=856
#   iteration 473 completed in 18s, avg 2.3 r/sec, next=2019-11-26 17:44:00, rate-limit=1169
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2019-12-26 14:24:00, rate-limit=986
# 524 iterations done in 206s, skipped 0, added 523836
#
# LTCUSDT - 2020
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2020-01-30 21:40:00, rate-limit=728
#   iteration 086 completed in 21s, avg 2.0 r/sec, next=2020-03-01 01:14:00, rate-limit=1180
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2020-03-31 01:02:00, rate-limit=947
#   iteration 172 completed in 20s, avg 2.1 r/sec, next=2020-04-30 00:12:00, rate-limit=701
#   iteration 215 completed in 20s, avg 2.1 r/sec, next=2020-05-29 20:52:00, rate-limit=454
#   iteration 258 completed in 16s, avg 2.6 r/sec, next=2020-06-28 21:02:00, rate-limit=984
#   iteration 301 completed in 15s, avg 2.8 r/sec, next=2020-07-28 17:42:00, rate-limit=789
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2020-08-27 14:22:00, rate-limit=588
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2020-09-26 11:02:00, rate-limit=1117
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2020-10-26 06:42:00, rate-limit=901
#   iteration 473 completed in 22s, avg 1.9 r/sec, next=2020-11-25 03:22:00, rate-limit=653
#   iteration 516 completed in 19s, avg 2.2 r/sec, next=2020-12-25 06:14:00, rate-limit=1140
# 526 iterations done in 226s, skipped 0, added 525766
#
# LTCUSDT - 2021
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2021-01-30 21:40:00, rate-limit=866
#   iteration 086 completed in 16s, avg 2.6 r/sec, next=2021-03-01 19:39:00, rate-limit=650
#   iteration 129 completed in 18s, avg 2.3 r/sec, next=2021-03-31 18:49:00, rate-limit=1149
#   iteration 172 completed in 17s, avg 2.5 r/sec, next=2021-04-30 22:42:00, rate-limit=940
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2021-05-30 19:22:00, rate-limit=715
#   iteration 258 completed in 18s, avg 2.3 r/sec, next=2021-06-29 16:02:00, rate-limit=468
#   iteration 301 completed in 19s, avg 2.2 r/sec, next=2021-07-29 12:42:00, rate-limit=989
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2021-08-28 13:52:00, rate-limit=785
#   iteration 387 completed in 16s, avg 2.6 r/sec, next=2021-09-27 10:32:00, rate-limit=562
#   iteration 430 completed in 13s, avg 3.3 r/sec, next=2021-10-27 09:12:00, rate-limit=1133
#   iteration 473 completed in 17s, avg 2.5 r/sec, next=2021-11-26 04:52:00, rate-limit=930
#   iteration 516 completed in 14s, avg 3.0 r/sec, next=2021-12-26 01:32:00, rate-limit=739
# 525 iterations done in 210s, skipped 0, added 524608
#
# LTCUSDT - 2022
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2022-01-30 21:40:00, rate-limit=490
#   iteration 086 completed in 19s, avg 2.2 r/sec, next=2022-03-01 18:20:00, rate-limit=1038
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2022-03-31 16:00:00, rate-limit=805
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2022-04-30 12:40:00, rate-limit=570
#   iteration 215 completed in 17s, avg 2.5 r/sec, next=2022-05-30 09:20:00, rate-limit=1157
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2022-06-29 06:00:00, rate-limit=937
# 261 iterations done in 103s, skipped 0, added 260640
#
# First Timestamp of EOSUSDT is at 2018-05-28 07:00:00
# EOSUSDT - 2018
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2018-06-27 13:40:00, rate-limit=686
#   iteration 086 completed in 18s, avg 2.3 r/sec, next=2018-07-27 19:42:00, rate-limit=1181
#   iteration 129 completed in 19s, avg 2.2 r/sec, next=2018-08-26 16:22:00, rate-limit=925
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2018-09-25 13:02:00, rate-limit=699
#   iteration 215 completed in 21s, avg 2.0 r/sec, next=2018-10-25 13:12:00, rate-limit=451
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2018-11-24 15:52:00, rate-limit=994
#   iteration 301 completed in 17s, avg 2.5 r/sec, next=2018-12-24 12:32:00, rate-limit=763
# 312 iterations done in 133s, skipped 0, added 311828
#
# EOSUSDT - 2019
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2019-01-30 21:40:00, rate-limit=500
#   iteration 086 completed in 15s, avg 2.8 r/sec, next=2019-03-01 18:20:00, rate-limit=1061
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2019-03-31 22:00:00, rate-limit=850
#   iteration 172 completed in 19s, avg 2.2 r/sec, next=2019-04-30 18:40:00, rate-limit=612
#   iteration 215 completed in 17s, avg 2.5 r/sec, next=2019-05-31 01:20:00, rate-limit=1164
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2019-06-29 23:01:00, rate-limit=943
#   iteration 301 completed in 15s, avg 2.8 r/sec, next=2019-07-29 19:41:00, rate-limit=738
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2019-08-29 00:21:00, rate-limit=552
#   iteration 387 completed in 18s, avg 2.3 r/sec, next=2019-09-27 21:01:00, rate-limit=1067
#   iteration 430 completed in 14s, avg 3.0 r/sec, next=2019-10-27 16:41:00, rate-limit=867
#   iteration 473 completed in 17s, avg 2.5 r/sec, next=2019-11-26 17:44:00, rate-limit=645
#   iteration 516 completed in 17s, avg 2.5 r/sec, next=2019-12-26 14:24:00, rate-limit=1194
# 524 iterations done in 206s, skipped 0, added 523836
#
# EOSUSDT - 2020
#   iteration 043 completed in 14s, avg 3.0 r/sec, next=2020-01-30 21:40:00, rate-limit=962
#   iteration 086 completed in 24s, avg 1.7 r/sec, next=2020-03-01 01:14:00, rate-limit=676
#   iteration 129 completed in 19s, avg 2.2 r/sec, next=2020-03-31 01:02:00, rate-limit=1188
#   iteration 172 completed in 15s, avg 2.8 r/sec, next=2020-04-30 00:12:00, rate-limit=971
#   iteration 215 completed in 17s, avg 2.5 r/sec, next=2020-05-29 20:52:00, rate-limit=763
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2020-06-28 21:02:00, rate-limit=540
#   iteration 301 completed in 15s, avg 2.8 r/sec, next=2020-07-28 17:42:00, rate-limit=1095
#   iteration 344 completed in 19s, avg 2.2 r/sec, next=2020-08-27 14:22:00, rate-limit=867
#   iteration 387 completed in 18s, avg 2.3 r/sec, next=2020-09-26 11:02:00, rate-limit=639
#   iteration 430 completed in 16s, avg 2.6 r/sec, next=2020-10-26 06:42:00, rate-limit=1165
#   iteration 473 completed in 22s, avg 1.9 r/sec, next=2020-11-25 03:22:00, rate-limit=927
#   iteration 516 completed in 20s, avg 2.1 r/sec, next=2020-12-25 06:14:00, rate-limit=685
# 526 iterations done in 225s, skipped 0, added 525766
#
# EOSUSDT - 2021
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2021-01-30 21:40:00, rate-limit=1139
#   iteration 086 completed in 19s, avg 2.2 r/sec, next=2021-03-01 19:39:00, rate-limit=901
#   iteration 129 completed in 17s, avg 2.5 r/sec, next=2021-03-31 18:49:00, rate-limit=674
#   iteration 172 completed in 14s, avg 3.0 r/sec, next=2021-04-30 22:43:00, rate-limit=458
#   iteration 215 completed in 24s, avg 1.7 r/sec, next=2021-05-30 19:23:00, rate-limit=976
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2021-06-29 16:03:00, rate-limit=746
#   iteration 301 completed in 16s, avg 2.6 r/sec, next=2021-07-29 12:43:00, rate-limit=527
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2021-08-28 13:53:00, rate-limit=1053
#   iteration 387 completed in 13s, avg 3.3 r/sec, next=2021-09-27 10:33:00, rate-limit=871
#   iteration 430 completed in 17s, avg 2.5 r/sec, next=2021-10-27 09:13:00, rate-limit=638
#   iteration 473 completed in 18s, avg 2.3 r/sec, next=2021-11-26 04:53:00, rate-limit=1188
#   iteration 516 completed in 17s, avg 2.5 r/sec, next=2021-12-26 01:33:00, rate-limit=965
# 525 iterations done in 212s, skipped 0, added 524607
#
# EOSUSDT - 2022
#   iteration 043 completed in 14s, avg 3.0 r/sec, next=2022-01-30 21:40:00, rate-limit=724
#   iteration 086 completed in 15s, avg 2.8 r/sec, next=2022-03-01 18:20:00, rate-limit=530
#   iteration 129 completed in 14s, avg 3.0 r/sec, next=2022-03-31 16:00:00, rate-limit=1119
#   iteration 172 completed in 15s, avg 2.8 r/sec, next=2022-04-30 12:40:00, rate-limit=916
#   iteration 215 completed in 14s, avg 3.0 r/sec, next=2022-05-30 09:20:00, rate-limit=700
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2022-06-29 06:00:00, rate-limit=480
# 261 iterations done in 93s, skipped 0, added 260640
#
# First Timestamp of XLMUSDT is at 2018-05-31 11:30:00
# XLMUSDT - 2018
#   iteration 043 completed in 14s, avg 3.0 r/sec, next=2018-06-30 19:55:00, rate-limit=1068
#   iteration 086 completed in 15s, avg 2.8 r/sec, next=2018-07-31 00:12:00, rate-limit=861
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2018-08-29 20:52:00, rate-limit=633
#   iteration 172 completed in 17s, avg 2.5 r/sec, next=2018-09-28 17:32:00, rate-limit=428
#   iteration 215 completed in 15s, avg 2.8 r/sec, next=2018-10-28 16:42:00, rate-limit=1007
#   iteration 258 completed in 15s, avg 2.8 r/sec, next=2018-11-27 20:22:00, rate-limit=780
#   iteration 301 completed in 21s, avg 2.0 r/sec, next=2018-12-27 17:02:00, rate-limit=544
# 308 iterations done in 118s, skipped 0, added 307238
#
# XLMUSDT - 2019
#   iteration 043 completed in 15s, avg 2.8 r/sec, next=2019-01-30 21:40:00, rate-limit=1063
#   iteration 086 completed in 14s, avg 3.0 r/sec, next=2019-03-01 18:20:00, rate-limit=865
#   iteration 129 completed in 18s, avg 2.3 r/sec, next=2019-03-31 22:00:00, rate-limit=681
#   iteration 172 completed in 17s, avg 2.5 r/sec, next=2019-04-30 18:40:00, rate-limit=1198
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2019-05-31 01:20:00, rate-limit=1012
#   iteration 258 completed in 21s, avg 2.0 r/sec, next=2019-06-29 23:01:00, rate-limit=820
#   iteration 301 completed in 16s, avg 2.6 r/sec, next=2019-07-29 19:41:00, rate-limit=673
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2019-08-29 00:21:00, rate-limit=1060
#   iteration 387 completed in 17s, avg 2.5 r/sec, next=2019-09-27 21:01:00, rate-limit=881
#   iteration 430 completed in 15s, avg 2.8 r/sec, next=2019-10-27 16:41:00, rate-limit=728
#   iteration 473 completed in 16s, avg 2.6 r/sec, next=2019-11-26 17:44:00, rate-limit=1171
#   iteration 516 completed in 16s, avg 2.6 r/sec, next=2019-12-26 14:24:00, rate-limit=1002
# 524 iterations done in 209s, skipped 0, added 523836
#
# XLMUSDT - 2020
#   iteration 043 completed in 16s, avg 2.6 r/sec, next=2020-01-30 21:40:00, rate-limit=801
#   iteration 086 completed in 18s, avg 2.3 r/sec, next=2020-03-01 01:14:00, rate-limit=617
#   iteration 129 completed in 18s, avg 2.3 r/sec, next=2020-03-31 01:02:00, rate-limit=1046
#   iteration 172 completed in 17s, avg 2.5 r/sec, next=2020-04-30 00:12:00, rate-limit=901
#   iteration 215 completed in 14s, avg 3.0 r/sec, next=2020-05-29 20:52:00, rate-limit=749
#   iteration 258 completed in 14s, avg 3.0 r/sec, next=2020-06-28 21:02:00, rate-limit=1171
#   iteration 301 completed in 17s, avg 2.5 r/sec, next=2020-07-28 17:42:00, rate-limit=1020
#   iteration 344 completed in 16s, avg 2.6 r/sec, next=2020-08-27 14:22:00, rate-limit=854
#   iteration 387 completed in 15s, avg 2.8 r/sec, next=2020-09-26 11:02:00, rate-limit=697
#   iteration 430 completed in 17s, avg 2.5 r/sec, next=2020-10-26 06:42:00, rate-limit=1111
#   iteration 473 completed in 17s, avg 2.5 r/sec, next=2020-11-25 03:22:00, rate-limit=931
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2020-12-25 06:14:00, rate-limit=767
# 526 iterations done in 203s, skipped 0, added 525766
#
# XLMUSDT - 2021
#   iteration 043 completed in 20s, avg 2.1 r/sec, next=2021-01-30 21:40:00, rate-limit=1164
#   iteration 086 completed in 18s, avg 2.3 r/sec, next=2021-03-01 19:39:00, rate-limit=1022
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2021-03-31 18:49:00, rate-limit=884
#   iteration 172 completed in 19s, avg 2.2 r/sec, next=2021-04-30 22:42:00, rate-limit=1197
#   iteration 215 completed in 19s, avg 2.2 r/sec, next=2021-05-30 19:22:00, rate-limit=1051
#   iteration 258 completed in 20s, avg 2.1 r/sec, next=2021-06-29 16:02:00, rate-limit=906
#   iteration 301 completed in 21s, avg 2.0 r/sec, next=2021-07-29 12:42:00, rate-limit=1188
#   iteration 344 completed in 18s, avg 2.3 r/sec, next=2021-08-28 13:52:00, rate-limit=1037
#   iteration 387 completed in 16s, avg 2.6 r/sec, next=2021-09-27 10:32:00, rate-limit=907
#   iteration 430 completed in 23s, avg 1.8 r/sec, next=2021-10-27 09:12:00, rate-limit=1199
#   iteration 473 completed in 15s, avg 2.8 r/sec, next=2021-11-26 04:52:00, rate-limit=1074
#   iteration 516 completed in 15s, avg 2.8 r/sec, next=2021-12-26 01:32:00, rate-limit=940
# 525 iterations done in 228s, skipped 0, added 524608
#
# XLMUSDT - 2022
#   iteration 043 completed in 17s, avg 2.5 r/sec, next=2022-01-30 21:40:00, rate-limit=806
#   iteration 086 completed in 16s, avg 2.6 r/sec, next=2022-03-01 18:20:00, rate-limit=1127
#   iteration 129 completed in 15s, avg 2.8 r/sec, next=2022-03-31 16:00:00, rate-limit=999
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2022-04-30 12:40:00, rate-limit=876
#   iteration 215 completed in 16s, avg 2.6 r/sec, next=2022-05-30 09:20:00, rate-limit=749
#   iteration 258 completed in 14s, avg 3.0 r/sec, next=2022-06-29 06:00:00, rate-limit=1105
# 261 iterations done in 97s, skipped 0, added 260640
#
# First Timestamp of SHIBUSDT is at 2021-05-10 13:00:00
# SHIBUSDT - 2021
#   iteration 043 completed in 18s, avg 2.3 r/sec, next=2021-06-09 09:40:00, rate-limit=957
#   iteration 086 completed in 20s, avg 2.1 r/sec, next=2021-07-09 06:20:00, rate-limit=818
#   iteration 129 completed in 16s, avg 2.6 r/sec, next=2021-08-08 03:00:00, rate-limit=1130
#   iteration 172 completed in 15s, avg 2.8 r/sec, next=2021-09-07 04:10:00, rate-limit=998
#   iteration 215 completed in 20s, avg 2.1 r/sec, next=2021-10-07 02:50:00, rate-limit=861
#   iteration 258 completed in 17s, avg 2.5 r/sec, next=2021-11-05 22:30:00, rate-limit=1183
#   iteration 301 completed in 17s, avg 2.5 r/sec, next=2021-12-05 19:10:00, rate-limit=1046
# 339 iterations done in 145s, skipped 0, added 338790
#
# SHIBUSDT - 2022
#   iteration 043 completed in 16s, avg 2.6 r/sec, next=2022-01-30 21:40:00, rate-limit=804
#   iteration 086 completed in 19s, avg 2.2 r/sec, next=2022-03-01 18:20:00, rate-limit=1093
#   iteration 129 completed in 23s, avg 1.8 r/sec, next=2022-03-31 16:00:00, rate-limit=949
#   iteration 172 completed in 16s, avg 2.6 r/sec, next=2022-04-30 12:40:00, rate-limit=824
#   iteration 215 completed in 18s, avg 2.3 r/sec, next=2022-05-30 09:20:00, rate-limit=1121
#   iteration 258 completed in 22s, avg 1.9 r/sec, next=2022-06-29 06:00:00, rate-limit=988
# 261 iterations done in 118s, skipped 0, added 260640
